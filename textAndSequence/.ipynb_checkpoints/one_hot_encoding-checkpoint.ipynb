# %%
import numpy as np

samples = ['The cat sat on the mat','The dog ate my homewark']

token_index = {}
for sample in samples:
    for word in sample.split():
        if word not in token_index:
            token_index[word] = len(token_index)+1
            
print(token_index)
max_length=10

results = np.zeros(shape=(len(samples),max_length,max(token_index.values())+1)) #[2,10,11]

for i,sample in enumerate(samples):
    for j,word in list(enumerate(sample.split()))[:max_length]:
        index = token_index.get(word)
        results[i,j,index]=1.
# Out:
# {'The': 1, 'cat': 2, 'sat': 3, 'on': 4, 'the': 5, 'mat': 6, 'dog': 7, 'ate': 8, 'my': 9, 'homewark': 10}
# <enumerate object at 0x000001C5981AAD40>
