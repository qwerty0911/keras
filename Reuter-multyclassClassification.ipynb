# %%
from keras.datasets import reuters
(train_data, train_labels),(test_data, test_labels) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# C:\Users\beomk\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\reuters.py:148: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\beomk\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\reuters.py:149: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
print(len(train_data))
print(len(train_labels))
print(len(test_data))
print(len(test_labels))
# Out:
# 8982
# 8982
# 2246
# 2246

# %%
from keras.datasets import reuters
word_index = reuters.get_word_index()
reverse_word_index  = dict([(value,key)for (key,value) in word_index.items()])

print(train_data[0])
for i in train_data[0]:
    print(i, reverse_word_index[i])
# Out:
# [1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]
# 1 the
# 2 of
# 2 of
# 8 mln
# 43 loss
# 10 for
# 447 plc
# 5 said
# 25 at
# 207 only
# 270 ended
# 5 said
# 3095 commonwealth
# 111 could
# 16 1
# 369 traders
# 186 now
# 90 april
# 67 0
# 7 a
# 89 after
# 5 said
# 19 from
# 102 1985
# 6 and
# 19 from
# 124 foreign
# 15 000
# 90 april
# 67 0
# 84 prices
# 22 its
# 482 account
# 26 year
# 7 a
# 48 but
# 4 in
# 49 this
# 8 mln
# 864 home
# 39 an
# 209 states
# 154 earlier
# 6 and
# 151 rise
# 6 and
# 83 revs
# 11 vs
# 15 000
# 22 its
# 155 16
# 11 vs
# 15 000
# 7 a
# 48 but
# 9 3
# 4579 psbr
# 1005 oils
# 504 several
# 6 and
# 258 shareholders
# 6 and
# 272 dividend
# 11 vs
# 15 000
# 22 its
# 134 all
# 44 4
# 11 vs
# 15 000
# 16 1
# 8 mln
# 197 agreed
# 1245 largely
# 90 april
# 67 0
# 52 are
# 29 2
# 209 states
# 30 will
# 32 billion
# 132 total
# 6 and
# 109 against
# 15 000
# 17 pct
# 12 dlrs

# %%
# Out:
# 'mdbl'

# %%
train_labels
# Out:
# array([ 3,  4,  3, ..., 25,  3, 25], dtype=int64)

# %%
import numpy as np

def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels),dimension))
    for i,label in enumerate(labels):
        results[i,label] = 1
    return results

one_hot_train_labels = to_one_hot(train_labels)
one_hot_test_labels = to_one_hot(test_labels)

# %%
from keras import models, layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
             loss='categorical_crossentropy',
             metrics=['accuracy'])
